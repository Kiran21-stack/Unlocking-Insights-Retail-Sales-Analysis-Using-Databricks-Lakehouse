# %%
# %sql
CREATE TABLE analytics.gold.monthlypricing
USING DELTA
LOCATION 'abfss://gold@retailkiran.dfs.core.windows.net/monthlypricing'
AS
SELECT * FROM kirandb.retail.monthly_pricing_summary;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5296490550491972>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "CREATE TABLE analytics.gold.monthlypricing\nUSING DELTA\nLOCATION 'abfss://gold@retailkiran.dfs.core.windows.net/monthlypricing'\nAS\nSELECT * FROM kirandb.retail.monthly_pricing_summary;\n")
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
CREATE TABLE analytics.gold.quarterlypricing
USING DELTA
LOCATION 'abfss://gold@retailkiran.dfs.core.windows.net/quarterlypricing'
AS
SELECT * FROM kirandb.retail.quarterly_pricing_analysis;

    
CREATE TABLE analytics.gold.yearlytrends
USING DELTA
LOCATION 'abfss://gold@retailkiran.dfs.core.windows.net/yearlytrends'
AS
SELECT * FROM kirandb.retail.year_price_trend;
    
CREATE TABLE analytics.gold.productreturnanalysis
USING DELTA   
LOCATION 'abfss://gold@retailkiran.dfs.core.windows.net/productreturnanalysis'
AS
SELECT * FROM kirandb.retail.product_return_analysis;

# %%
# %sql
CREATE TABLE analytics.gold.customersummary
USING DELTA
LOCATION 'abfss://gold@retailkiran.dfs.core.windows.net/customersummary'
AS
SELECT * FROM kirandb.retail.customer_summary;

CREATE TABLE analytics.gold.lineitemcomparison
USING DELTA
LOCATION 'abfss://gold@retailkiran.dfs.core.windows.net/lineitemcomparison'
AS
SELECT * FROM kirandb.retail.line_item_comparison;

CREATE TABLE analytics.gold.geodata
USING DELTA
LOCATION 'abfss://gold@retailkiran.dfs.core.windows.net/geodata'
AS
SELECT * FROM kirandb.retail.geo;
